# %% [markdown]
# ## siamese network

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import tensorflow as tf
from pathlib import Path
from tensorflow.keras import applications
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import Model
from tensorflow.keras.applications import resnet
# Out:
# 2022-11-29 21:38:02.219263: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-29 21:38:02.873947: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-29 21:38:02.873994: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-29 21:38:03.011769: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-29 21:38:05.971532: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-29 21:38:05.971822: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-29 21:38:05.971852: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
target_shape = (400,400)

# %%
def preprocess_image(filename):
    """
    Load the specified file as a JPEG image, preprocess it and
    resize it to the target shape.
    """

    image_string = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(image_string, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, target_shape)
    return image

# %%
def preprocess_triplets(anchor, positive, negative):
    """
    Given the filenames corresponding to the three images, load and
    preprocess them.
    """

    return (
        preprocess_image(anchor),
        preprocess_image(positive),
        preprocess_image(negative),
    )

# %%
anchor_images_path = "original_sg"
positive_images_path = "snoise_sg"

# %%
anchor_images = [str(anchor_images_path+'/'+f) for f in os.listdir(anchor_images_path)][0:1000]
positive_images = [str(positive_images_path+'/'+f) for f in os.listdir(positive_images_path)][0:1000]

# %%
anchor_images
# Out:
# ['original_sg/s_1922.jpg',
#  'original_sg/s_943.jpg',
#  'original_sg/s_5090.jpg',
#  'original_sg/s_5864.jpg',
#  'original_sg/s_5708.jpg',
#  'original_sg/s_2751.jpg',
#  'original_sg/s_3373.jpg',
#  'original_sg/s_375.jpg',
#  'original_sg/s_3165.jpg',
#  'original_sg/s_3509.jpg',
#  'original_sg/s_2388.jpg',
#  'original_sg/s_3074.jpg',
#  'original_sg/s_2408.jpg',
#  'original_sg/s_3310.jpg',
#  'original_sg/s_5946.jpg',
#  'original_sg/s_1731.jpg',
#  'original_sg/s_6423.jpg',
#  'original_sg/s_1192.jpg',
#  'original_sg/s_4343.jpg',
#  'original_sg/s_4649.jpg',
#  'original_sg/s_2327.jpg',
#  'original_sg/s_4609.jpg',
#  'original_sg/s_6032.jpg',
#  'original_sg/s_4267.jpg',
#  'original_sg/s_2590.jpg',
#  'original_sg/s_4034.jpg',
#  'original_sg/s_5522.jpg',
#  'original_sg/s_1323.jpg',
#  'original_sg/s_6405.jpg',
#  'original_sg/s_2766.jpg',
#  'original_sg/s_6249.jpg',
#  'original_sg/s_753.jpg',
#  'original_sg/s_5764.jpg',
#  'original_sg/s_379.jpg',
#  'original_sg/s_3873.jpg',
#  'original_sg/s_704.jpg',
#  'original_sg/s_2019.jpg',
#  'original_sg/s_5469.jpg',
#  'original_sg/s_2831.jpg',
#  'original_sg/s_1302.jpg',
#  'original_sg/s_5926.jpg',
#  'original_sg/s_5625.jpg',
#  'original_sg/s_880.jpg',
#  'original_sg/s_4032.jpg',
#  'original_sg/s_3529.jpg',
#  'original_sg/s_3301.jpg',
#  'original_sg/s_1235.jpg',
#  'original_sg/s_4799.jpg',
#  'original_sg/s_4854.jpg',
#  'original_sg/s_3993.jpg',
#  'original_sg/s_5185.jpg',
#  'original_sg/s_504.jpg',
#  'original_sg/s_1737.jpg',
#  'original_sg/s_211.jpg',
#  'original_sg/s_5421.jpg',
#  'original_sg/s_1258.jpg',
#  'original_sg/s_2317.jpg',
#  'original_sg/s_4340.jpg',
#  'original_sg/s_5007.jpg',
#  'original_sg/s_219.jpg',
#  'original_sg/s_2402.jpg',
#  'original_sg/s_663.jpg',
#  'original_sg/s_4850.jpg',
#  'original_sg/s_245.jpg',
#  'original_sg/s_5781.jpg',
#  'original_sg/s_3984.jpg',
#  'original_sg/s_3272.jpg',
#  'original_sg/s_2404.jpg',
#  'original_sg/s_1930.jpg',
#  'original_sg/s_3946.jpg',
#  'original_sg/s_4505.jpg',
#  'original_sg/s_1289.jpg',
#  'original_sg/s_2104.jpg',
#  'original_sg/s_4121.jpg',
#  'original_sg/s_660.jpg',
#  'original_sg/s_6461.jpg',
#  'original_sg/s_5953.jpg',
#  'original_sg/s_3621.jpg',
#  'original_sg/s_3432.jpg',
#  'original_sg/s_2496.jpg',
#  'original_sg/s_3280.jpg',
#  'original_sg/s_5646.jpg',
#  'original_sg/s_6173.jpg',
#  'original_sg/s_795.jpg',
#  'original_sg/s_5411.jpg',
#  'original_sg/s_3585.jpg',
#  'original_sg/s_2005.jpg',
#  'original_sg/s_3371.jpg',
#  'original_sg/s_1091.jpg',
#  'original_sg/s_6291.jpg',
#  'original_sg/s_3072.jpg',
#  'original_sg/s_126.jpg',
#  'original_sg/s_2599.jpg',
#  'original_sg/s_5052.jpg',
#  'original_sg/s_5715.jpg',
#  'original_sg/s_2208.jpg',
#  'original_sg/s_3752.jpg',
#  'original_sg/s_844.jpg',
#  'original_sg/s_1591.jpg',
#  'original_sg/s_4562.jpg',
#  'original_sg/s_1999.jpg',
#  'original_sg/s_708.jpg',
#  'original_sg/s_1300.jpg',
#  'original_sg/s_488.jpg',
#  'original_sg/s_676.jpg',
#  'original_sg/s_3627.jpg',
#  'original_sg/s_4947.jpg',
#  'original_sg/s_5654.jpg',
#  'original_sg/s_3490.jpg',
#  'original_sg/s_894.jpg',
#  'original_sg/s_765.jpg',
#  'original_sg/s_423.jpg',
#  'original_sg/s_2748.jpg',
#  'original_sg/s_3209.jpg',
#  'original_sg/s_750.jpg',
#  'original_sg/s_1582.jpg',
#  'original_sg/s_1259.jpg',
#  'original_sg/s_1054.jpg',
#  'original_sg/s_6339.jpg',
#  'original_sg/s_3538.jpg',
#  'original_sg/s_1974.jpg',
#  'original_sg/s_20.jpg',
#  'original_sg/s_4890.jpg',
#  'original_sg/s_5097.jpg',
#  'original_sg/s_1333.jpg',
#  'original_sg/s_873.jpg',
#  'original_sg/s_4097.jpg',
#  'original_sg/s_83.jpg',
#  'original_sg/s_4887.jpg',
#  'original_sg/s_433.jpg',
#  'original_sg/s_333.jpg',
#  'original_sg/s_572.jpg',
#  'original_sg/s_665.jpg',
#  'original_sg/s_1246.jpg',
#  'original_sg/s_2245.jpg',
#  'original_sg/s_6077.jpg',
#  'original_sg/s_236.jpg',
#  'original_sg/s_3413.jpg',
#  'original_sg/s_809.jpg',
#  'original_sg/s_261.jpg',
#  'original_sg/s_1697.jpg',
#  'original_sg/s_3910.jpg',
#  'original_sg/s_1071.jpg',
#  'original_sg/s_436.jpg',
#  'original_sg/s_5940.jpg',
#  'original_sg/s_2382.jpg',
#  'original_sg/s_3912.jpg',
#  'original_sg/s_406.jpg',
#  'original_sg/s_3352.jpg',
#  'original_sg/s_5094.jpg',
#  'original_sg/s_2675.jpg',
#  'original_sg/s_3459.jpg',
#  'original_sg/s_1946.jpg',
#  'original_sg/s_443.jpg',
#  'original_sg/s_2146.jpg',
#  'original_sg/s_1623.jpg',
#  'original_sg/s_3022.jpg',
#  'original_sg/s_3124.jpg',
#  'original_sg/s_1982.jpg',
#  'original_sg/s_5318.jpg',
#  'original_sg/s_5874.jpg',
#  'original_sg/s_2434.jpg',
#  'original_sg/s_1595.jpg',
#  'original_sg/s_3141.jpg',
#  'original_sg/s_3687.jpg',
#  'original_sg/s_2468.jpg',
#  'original_sg/s_6373.jpg',
#  'original_sg/s_874.jpg',
#  'original_sg/s_6154.jpg',
#  'original_sg/s_4561.jpg',
#  'original_sg/s_2273.jpg',
#  'original_sg/s_3400.jpg',
#  'original_sg/s_3516.jpg',
#  'original_sg/s_5006.jpg',
#  'original_sg/s_2716.jpg',
#  'original_sg/s_6413.jpg',
#  'original_sg/s_3987.jpg',
#  'original_sg/s_1070.jpg',
#  'original_sg/s_600.jpg',
#  'original_sg/s_638.jpg',
#  'original_sg/s_2413.jpg',
#  'original_sg/s_6419.jpg',
#  'original_sg/s_187.jpg',
#  'original_sg/s_5336.jpg',
#  'original_sg/s_1994.jpg',
#  'original_sg/s_3121.jpg',
#  'original_sg/s_3450.jpg',
#  'original_sg/s_5026.jpg',
#  'original_sg/s_863.jpg',
#  'original_sg/s_281.jpg',
#  'original_sg/s_2924.jpg',
#  'original_sg/s_5846.jpg',
#  'original_sg/s_16.jpg',
#  'original_sg/s_2853.jpg',
#  'original_sg/s_6028.jpg',
#  'original_sg/s_3279.jpg',
#  'original_sg/s_5758.jpg',
#  'original_sg/s_4920.jpg',
#  'original_sg/s_2995.jpg',
#  'original_sg/s_4895.jpg',
#  'original_sg/s_1726.jpg',
#  'original_sg/s_6313.jpg',
#  'original_sg/s_280.jpg',
#  'original_sg/s_5234.jpg',
#  'original_sg/s_336.jpg',
#  'original_sg/s_114.jpg',
#  'original_sg/s_1050.jpg',
#  'original_sg/s_4809.jpg',
#  'original_sg/s_1106.jpg',
#  'original_sg/s_6460.jpg',
#  'original_sg/s_1601.jpg',
#  'original_sg/s_6271.jpg',
#  'original_sg/s_1024.jpg',
#  'original_sg/s_5216.jpg',
#  'original_sg/s_2396.jpg',
#  'original_sg/s_3810.jpg',
#  'original_sg/s_1770.jpg',
#  'original_sg/s_4134.jpg',
#  'original_sg/s_5491.jpg',
#  'original_sg/s_6268.jpg',
#  'original_sg/s_2120.jpg',
#  'original_sg/s_5769.jpg',
#  'original_sg/s_3261.jpg',
#  'original_sg/s_1746.jpg',
#  'original_sg/s_1890.jpg',
#  'original_sg/s_1164.jpg',
#  'original_sg/s_3740.jpg',
#  'original_sg/s_5338.jpg',
#  'original_sg/s_5814.jpg',
#  'original_sg/s_4160.jpg',
#  'original_sg/s_2076.jpg',
#  'original_sg/s_3360.jpg',
#  'original_sg/s_1676.jpg',
#  'original_sg/s_3085.jpg',
#  'original_sg/s_1859.jpg',
#  'original_sg/s_441.jpg',
#  'original_sg/s_4029.jpg',
#  'original_sg/s_1611.jpg',
#  'original_sg/s_5145.jpg',
#  'original_sg/s_5238.jpg',
#  'original_sg/s_5583.jpg',
#  'original_sg/s_6364.jpg',
#  'original_sg/s_6122.jpg',
#  'original_sg/s_6275.jpg',
#  'original_sg/s_2070.jpg',
#  'original_sg/s_1593.jpg',
#  'original_sg/s_4889.jpg',
#  'original_sg/s_445.jpg',
#  'original_sg/s_5132.jpg',
#  'original_sg/s_399.jpg',
#  'original_sg/s_4475.jpg',
#  'original_sg/s_1704.jpg',
#  'original_sg/s_6355.jpg',
#  'original_sg/s_2171.jpg',
#  'original_sg/s_3309.jpg',
#  'original_sg/s_3100.jpg',
#  'original_sg/s_878.jpg',
#  'original_sg/s_697.jpg',
#  'original_sg/s_4054.jpg',
#  'original_sg/s_258.jpg',
#  'original_sg/s_5754.jpg',
#  'original_sg/s_4557.jpg',
#  'original_sg/s_1842.jpg',
#  'original_sg/s_2225.jpg',
#  'original_sg/s_3158.jpg',
#  'original_sg/s_5495.jpg',
#  'original_sg/s_2591.jpg',
#  'original_sg/s_3609.jpg',
#  'original_sg/s_794.jpg',
#  'original_sg/s_599.jpg',
#  'original_sg/s_4985.jpg',
#  'original_sg/s_5241.jpg',
#  'original_sg/s_76.jpg',
#  'original_sg/s_1877.jpg',
#  'original_sg/s_4326.jpg',
#  'original_sg/s_477.jpg',
#  'original_sg/s_5524.jpg',
#  'original_sg/s_2633.jpg',
#  'original_sg/s_5366.jpg',
#  'original_sg/s_4081.jpg',
#  'original_sg/s_4979.jpg',
#  'original_sg/s_4810.jpg',
#  'original_sg/s_5696.jpg',
#  'original_sg/s_6436.jpg',
#  'original_sg/s_3236.jpg',
#  'original_sg/s_5315.jpg',
#  'original_sg/s_1666.jpg',
#  'original_sg/s_1155.jpg',
#  'original_sg/s_5135.jpg',
#  'original_sg/s_4808.jpg',
#  'original_sg/s_1551.jpg',
#  'original_sg/s_4203.jpg',
#  'original_sg/s_694.jpg',
#  'original_sg/s_4555.jpg',
#  'original_sg/s_1390.jpg',
#  'original_sg/s_4546.jpg',
#  'original_sg/s_3506.jpg',
#  'original_sg/s_6181.jpg',
#  'original_sg/s_1787.jpg',
#  'original_sg/s_3018.jpg',
#  'original_sg/s_5867.jpg',
#  'original_sg/s_290.jpg']

# %%
positive_images
# Out:
# ['snoise_sg/s_1922.jpg',
#  'snoise_sg/s_943.jpg',
#  'snoise_sg/s_5090.jpg',
#  'snoise_sg/s_5864.jpg',
#  'snoise_sg/s_5708.jpg',
#  'snoise_sg/s_2751.jpg',
#  'snoise_sg/s_3373.jpg',
#  'snoise_sg/s_375.jpg',
#  'snoise_sg/s_3165.jpg',
#  'snoise_sg/s_3509.jpg',
#  'snoise_sg/s_2388.jpg',
#  'snoise_sg/s_3074.jpg',
#  'snoise_sg/s_2408.jpg',
#  'snoise_sg/s_3310.jpg',
#  'snoise_sg/s_5946.jpg',
#  'snoise_sg/s_1731.jpg',
#  'snoise_sg/s_6423.jpg',
#  'snoise_sg/s_1192.jpg',
#  'snoise_sg/s_4343.jpg',
#  'snoise_sg/s_4649.jpg',
#  'snoise_sg/s_2327.jpg',
#  'snoise_sg/s_4609.jpg',
#  'snoise_sg/s_6032.jpg',
#  'snoise_sg/s_4267.jpg',
#  'snoise_sg/s_2590.jpg',
#  'snoise_sg/s_4034.jpg',
#  'snoise_sg/s_5522.jpg',
#  'snoise_sg/s_1323.jpg',
#  'snoise_sg/s_6405.jpg',
#  'snoise_sg/s_2766.jpg',
#  'snoise_sg/s_6249.jpg',
#  'snoise_sg/s_753.jpg',
#  'snoise_sg/s_5764.jpg',
#  'snoise_sg/s_379.jpg',
#  'snoise_sg/s_3873.jpg',
#  'snoise_sg/s_704.jpg',
#  'snoise_sg/s_2019.jpg',
#  'snoise_sg/s_5469.jpg',
#  'snoise_sg/s_2831.jpg',
#  'snoise_sg/s_1302.jpg',
#  'snoise_sg/s_5926.jpg',
#  'snoise_sg/s_5625.jpg',
#  'snoise_sg/s_880.jpg',
#  'snoise_sg/s_4032.jpg',
#  'snoise_sg/s_3529.jpg',
#  'snoise_sg/s_3301.jpg',
#  'snoise_sg/s_1235.jpg',
#  'snoise_sg/s_4799.jpg',
#  'snoise_sg/s_4854.jpg',
#  'snoise_sg/s_3993.jpg',
#  'snoise_sg/s_5185.jpg',
#  'snoise_sg/s_504.jpg',
#  'snoise_sg/s_1737.jpg',
#  'snoise_sg/s_211.jpg',
#  'snoise_sg/s_5421.jpg',
#  'snoise_sg/s_1258.jpg',
#  'snoise_sg/s_2317.jpg',
#  'snoise_sg/s_4340.jpg',
#  'snoise_sg/s_5007.jpg',
#  'snoise_sg/s_219.jpg',
#  'snoise_sg/s_2402.jpg',
#  'snoise_sg/s_663.jpg',
#  'snoise_sg/s_4850.jpg',
#  'snoise_sg/s_245.jpg',
#  'snoise_sg/s_5781.jpg',
#  'snoise_sg/s_3984.jpg',
#  'snoise_sg/s_3272.jpg',
#  'snoise_sg/s_2404.jpg',
#  'snoise_sg/s_1930.jpg',
#  'snoise_sg/s_3946.jpg',
#  'snoise_sg/s_4505.jpg',
#  'snoise_sg/s_1289.jpg',
#  'snoise_sg/s_2104.jpg',
#  'snoise_sg/s_4121.jpg',
#  'snoise_sg/s_660.jpg',
#  'snoise_sg/s_6461.jpg',
#  'snoise_sg/s_5953.jpg',
#  'snoise_sg/s_3621.jpg',
#  'snoise_sg/s_3432.jpg',
#  'snoise_sg/s_2496.jpg',
#  'snoise_sg/s_3280.jpg',
#  'snoise_sg/s_5646.jpg',
#  'snoise_sg/s_6173.jpg',
#  'snoise_sg/s_795.jpg',
#  'snoise_sg/s_5411.jpg',
#  'snoise_sg/s_3585.jpg',
#  'snoise_sg/s_2005.jpg',
#  'snoise_sg/s_3371.jpg',
#  'snoise_sg/s_1091.jpg',
#  'snoise_sg/s_6291.jpg',
#  'snoise_sg/s_3072.jpg',
#  'snoise_sg/s_126.jpg',
#  'snoise_sg/s_2599.jpg',
#  'snoise_sg/s_5052.jpg',
#  'snoise_sg/s_5715.jpg',
#  'snoise_sg/s_2208.jpg',
#  'snoise_sg/s_3752.jpg',
#  'snoise_sg/s_844.jpg',
#  'snoise_sg/s_1591.jpg',
#  'snoise_sg/s_4562.jpg',
#  'snoise_sg/s_1999.jpg',
#  'snoise_sg/s_708.jpg',
#  'snoise_sg/s_1300.jpg',
#  'snoise_sg/s_488.jpg',
#  'snoise_sg/s_676.jpg',
#  'snoise_sg/s_3627.jpg',
#  'snoise_sg/s_4947.jpg',
#  'snoise_sg/s_5654.jpg',
#  'snoise_sg/s_3490.jpg',
#  'snoise_sg/s_894.jpg',
#  'snoise_sg/s_765.jpg',
#  'snoise_sg/s_423.jpg',
#  'snoise_sg/s_2748.jpg',
#  'snoise_sg/s_3209.jpg',
#  'snoise_sg/s_750.jpg',
#  'snoise_sg/s_1582.jpg',
#  'snoise_sg/s_1259.jpg',
#  'snoise_sg/s_1054.jpg',
#  'snoise_sg/s_6339.jpg',
#  'snoise_sg/s_3538.jpg',
#  'snoise_sg/s_1974.jpg',
#  'snoise_sg/s_20.jpg',
#  'snoise_sg/s_4890.jpg',
#  'snoise_sg/s_5097.jpg',
#  'snoise_sg/s_1333.jpg',
#  'snoise_sg/s_873.jpg',
#  'snoise_sg/s_4097.jpg',
#  'snoise_sg/s_83.jpg',
#  'snoise_sg/s_4887.jpg',
#  'snoise_sg/s_433.jpg',
#  'snoise_sg/s_333.jpg',
#  'snoise_sg/s_572.jpg',
#  'snoise_sg/s_665.jpg',
#  'snoise_sg/s_1246.jpg',
#  'snoise_sg/s_2245.jpg',
#  'snoise_sg/s_6077.jpg',
#  'snoise_sg/s_236.jpg',
#  'snoise_sg/s_3413.jpg',
#  'snoise_sg/s_809.jpg',
#  'snoise_sg/s_261.jpg',
#  'snoise_sg/s_1697.jpg',
#  'snoise_sg/s_3910.jpg',
#  'snoise_sg/s_1071.jpg',
#  'snoise_sg/s_436.jpg',
#  'snoise_sg/s_5940.jpg',
#  'snoise_sg/s_2382.jpg',
#  'snoise_sg/s_3912.jpg',
#  'snoise_sg/s_406.jpg',
#  'snoise_sg/s_3352.jpg',
#  'snoise_sg/s_5094.jpg',
#  'snoise_sg/s_2675.jpg',
#  'snoise_sg/s_3459.jpg',
#  'snoise_sg/s_1946.jpg',
#  'snoise_sg/s_443.jpg',
#  'snoise_sg/s_2146.jpg',
#  'snoise_sg/s_1623.jpg',
#  'snoise_sg/s_3022.jpg',
#  'snoise_sg/s_3124.jpg',
#  'snoise_sg/s_1982.jpg',
#  'snoise_sg/s_5318.jpg',
#  'snoise_sg/s_5874.jpg',
#  'snoise_sg/s_2434.jpg',
#  'snoise_sg/s_1595.jpg',
#  'snoise_sg/s_3141.jpg',
#  'snoise_sg/s_3687.jpg',
#  'snoise_sg/s_2468.jpg',
#  'snoise_sg/s_6373.jpg',
#  'snoise_sg/s_874.jpg',
#  'snoise_sg/s_6154.jpg',
#  'snoise_sg/s_4561.jpg',
#  'snoise_sg/s_2273.jpg',
#  'snoise_sg/s_3400.jpg',
#  'snoise_sg/s_3516.jpg',
#  'snoise_sg/s_5006.jpg',
#  'snoise_sg/s_2716.jpg',
#  'snoise_sg/s_6413.jpg',
#  'snoise_sg/s_3987.jpg',
#  'snoise_sg/s_1070.jpg',
#  'snoise_sg/s_600.jpg',
#  'snoise_sg/s_638.jpg',
#  'snoise_sg/s_2413.jpg',
#  'snoise_sg/s_6419.jpg',
#  'snoise_sg/s_187.jpg',
#  'snoise_sg/s_5336.jpg',
#  'snoise_sg/s_1994.jpg',
#  'snoise_sg/s_3121.jpg',
#  'snoise_sg/s_3450.jpg',
#  'snoise_sg/s_5026.jpg',
#  'snoise_sg/s_863.jpg',
#  'snoise_sg/s_281.jpg',
#  'snoise_sg/s_2924.jpg',
#  'snoise_sg/s_5846.jpg',
#  'snoise_sg/s_16.jpg',
#  'snoise_sg/s_2853.jpg',
#  'snoise_sg/s_6028.jpg',
#  'snoise_sg/s_3279.jpg',
#  'snoise_sg/s_5758.jpg',
#  'snoise_sg/s_4920.jpg',
#  'snoise_sg/s_2995.jpg',
#  'snoise_sg/s_4895.jpg',
#  'snoise_sg/s_1726.jpg',
#  'snoise_sg/s_6313.jpg',
#  'snoise_sg/s_280.jpg',
#  'snoise_sg/s_5234.jpg',
#  'snoise_sg/s_336.jpg',
#  'snoise_sg/s_114.jpg',
#  'snoise_sg/s_1050.jpg',
#  'snoise_sg/s_4809.jpg',
#  'snoise_sg/s_1106.jpg',
#  'snoise_sg/s_6460.jpg',
#  'snoise_sg/s_1601.jpg',
#  'snoise_sg/s_6271.jpg',
#  'snoise_sg/s_1024.jpg',
#  'snoise_sg/s_5216.jpg',
#  'snoise_sg/s_2396.jpg',
#  'snoise_sg/s_3810.jpg',
#  'snoise_sg/s_1770.jpg',
#  'snoise_sg/s_4134.jpg',
#  'snoise_sg/s_5491.jpg',
#  'snoise_sg/s_6268.jpg',
#  'snoise_sg/s_2120.jpg',
#  'snoise_sg/s_5769.jpg',
#  'snoise_sg/s_3261.jpg',
#  'snoise_sg/s_1746.jpg',
#  'snoise_sg/s_1890.jpg',
#  'snoise_sg/s_1164.jpg',
#  'snoise_sg/s_3740.jpg',
#  'snoise_sg/s_5338.jpg',
#  'snoise_sg/s_5814.jpg',
#  'snoise_sg/s_4160.jpg',
#  'snoise_sg/s_275.jpg',
#  'snoise_sg/s_4220.jpg',
#  'snoise_sg/s_3956.jpg',
#  'snoise_sg/s_3556.jpg',
#  'snoise_sg/s_3518.jpg',
#  'snoise_sg/s_1631.jpg',
#  'snoise_sg/s_5252.jpg',
#  'snoise_sg/s_1981.jpg',
#  'snoise_sg/s_5667.jpg',
#  'snoise_sg/s_2303.jpg',
#  'snoise_sg/s_13.jpg',
#  'snoise_sg/s_2871.jpg',
#  'snoise_sg/s_3331.jpg',
#  'snoise_sg/s_2840.jpg',
#  'snoise_sg/s_2421.jpg',
#  'snoise_sg/s_5597.jpg',
#  'snoise_sg/s_1707.jpg',
#  'snoise_sg/s_14.jpg',
#  'snoise_sg/s_1014.jpg',
#  'snoise_sg/s_5967.jpg',
#  'snoise_sg/s_4732.jpg',
#  'snoise_sg/s_5077.jpg',
#  'snoise_sg/s_544.jpg',
#  'snoise_sg/s_1037.jpg',
#  'snoise_sg/s_3665.jpg',
#  'snoise_sg/s_3374.jpg',
#  'snoise_sg/s_748.jpg',
#  'snoise_sg/s_6047.jpg',
#  'snoise_sg/s_4699.jpg',
#  'snoise_sg/s_5951.jpg',
#  'snoise_sg/s_5401.jpg',
#  'snoise_sg/s_781.jpg',
#  'snoise_sg/s_181.jpg',
#  'snoise_sg/s_1367.jpg',
#  'snoise_sg/s_3126.jpg',
#  'snoise_sg/s_2643.jpg',
#  'snoise_sg/s_3911.jpg',
#  'snoise_sg/s_439.jpg',
#  'snoise_sg/s_5180.jpg',
#  'snoise_sg/s_3668.jpg',
#  'snoise_sg/s_4503.jpg',
#  'snoise_sg/s_624.jpg',
#  'snoise_sg/s_2540.jpg',
#  'snoise_sg/s_5900.jpg',
#  'snoise_sg/s_2092.jpg',
#  'snoise_sg/s_2910.jpg',
#  'snoise_sg/s_3089.jpg',
#  'snoise_sg/s_4970.jpg',
#  'snoise_sg/s_489.jpg',
#  'snoise_sg/s_5213.jpg',
#  'snoise_sg/s_634.jpg',
#  'snoise_sg/s_6194.jpg',
#  'snoise_sg/s_5855.jpg',
#  'snoise_sg/s_3416.jpg',
#  'snoise_sg/s_5693.jpg',
#  'snoise_sg/s_774.jpg',
#  'snoise_sg/s_15.jpg',
#  'snoise_sg/s_5188.jpg',
#  'snoise_sg/s_5017.jpg',
#  'snoise_sg/s_4666.jpg',
#  'snoise_sg/s_2016.jpg',
#  'snoise_sg/s_2123.jpg',
#  'snoise_sg/s_6027.jpg',
#  'snoise_sg/s_1173.jpg',
#  'snoise_sg/s_563.jpg',
#  'snoise_sg/s_5678.jpg',
#  'snoise_sg/s_1085.jpg',
#  'snoise_sg/s_3478.jpg',
#  'snoise_sg/s_5552.jpg',
#  'snoise_sg/s_207.jpg',
#  'snoise_sg/s_6404.jpg',
#  'snoise_sg/s_5629.jpg',
#  'snoise_sg/s_4013.jpg',
#  'snoise_sg/s_6281.jpg',
#  'snoise_sg/s_2336.jpg',
#  'snoise_sg/s_2832.jpg',
#  'snoise_sg/s_4373.jpg',
#  'snoise_sg/s_1716.jpg',
#  'snoise_sg/s_896.jpg',
#  'snoise_sg/s_2727.jpg',
#  'snoise_sg/s_2587.jpg',
#  'snoise_sg/s_416.jpg',
#  'snoise_sg/s_6309.jpg',
#  'snoise_sg/s_5686.jpg',
#  'snoise_sg/s_5915.jpg',
#  'snoise_sg/s_4500.jpg',
#  'snoise_sg/s_92.jpg',
#  'snoise_sg/s_6279.jpg',
#  'snoise_sg/s_2613.jpg',
#  'snoise_sg/s_2945.jpg',
#  'snoise_sg/s_6245.jpg',
#  'snoise_sg/s_182.jpg',
#  'snoise_sg/s_2039.jpg',
#  'snoise_sg/s_355.jpg',
#  'snoise_sg/s_877.jpg',
#  'snoise_sg/s_5208.jpg',
#  'snoise_sg/s_6010.jpg',
#  'snoise_sg/s_329.jpg',
#  'snoise_sg/s_369.jpg',
#  'snoise_sg/s_822.jpg',
#  'snoise_sg/s_3191.jpg',
#  'snoise_sg/s_3844.jpg',
#  'snoise_sg/s_2038.jpg',
#  'snoise_sg/s_4719.jpg',
#  'snoise_sg/s_3961.jpg',
#  'snoise_sg/s_4168.jpg',
#  'snoise_sg/s_3886.jpg',
#  'snoise_sg/s_4806.jpg',
#  'snoise_sg/s_3950.jpg',
#  'snoise_sg/s_2814.jpg',
#  'snoise_sg/s_3859.jpg',
#  'snoise_sg/s_4274.jpg',
#  'snoise_sg/s_1021.jpg',
#  'snoise_sg/s_2067.jpg',
#  'snoise_sg/s_3697.jpg',
#  'snoise_sg/s_6228.jpg',
#  'snoise_sg/s_4380.jpg',
#  'snoise_sg/s_2722.jpg',
#  'snoise_sg/s_3517.jpg',
#  'snoise_sg/s_5363.jpg',
#  'snoise_sg/s_3522.jpg',
#  'snoise_sg/s_4048.jpg',
#  'snoise_sg/s_3988.jpg',
#  'snoise_sg/s_2479.jpg',
#  'snoise_sg/s_6463.jpg',
#  'snoise_sg/s_4028.jpg',
#  'snoise_sg/s_1481.jpg',
#  'snoise_sg/s_5386.jpg',
#  'snoise_sg/s_4857.jpg',
#  'snoise_sg/s_6314.jpg',
#  'snoise_sg/s_6074.jpg',
#  'snoise_sg/s_5532.jpg',
#  'snoise_sg/s_6124.jpg',
#  'snoise_sg/s_1781.jpg',
#  'snoise_sg/s_1346.jpg',
#  'snoise_sg/s_2272.jpg',
#  'snoise_sg/s_961.jpg',
#  'snoise_sg/s_1938.jpg',
#  'snoise_sg/s_2050.jpg',
#  'snoise_sg/s_1900.jpg',
#  'snoise_sg/s_4528.jpg',
#  'snoise_sg/s_2024.jpg',
#  'snoise_sg/s_160.jpg',
#  'snoise_sg/s_215.jpg',
#  'snoise_sg/s_529.jpg',
#  'snoise_sg/s_991.jpg',
#  'snoise_sg/s_320.jpg',
#  'snoise_sg/s_6406.jpg',
#  'snoise_sg/s_296.jpg',
#  'snoise_sg/s_4055.jpg',
#  'snoise_sg/s_2164.jpg',
#  'snoise_sg/s_4628.jpg',
#  'snoise_sg/s_5116.jpg',
#  'snoise_sg/s_2594.jpg',
#  'snoise_sg/s_354.jpg',
#  'snoise_sg/s_4772.jpg',
#  'snoise_sg/s_5604.jpg',
#  'snoise_sg/s_2839.jpg',
#  'snoise_sg/s_3551.jpg',
#  'snoise_sg/s_4691.jpg',
#  'snoise_sg/s_4938.jpg',
#  'snoise_sg/s_5702.jpg',
#  'snoise_sg/s_2355.jpg',
#  'snoise_sg/s_4208.jpg',
#  'snoise_sg/s_3704.jpg',
#  'snoise_sg/s_4539.jpg',
#  'snoise_sg/s_4897.jpg',
#  'snoise_sg/s_3482.jpg',
#  'snoise_sg/s_5995.jpg',
#  'snoise_sg/s_726.jpg',
#  'snoise_sg/s_6035.jpg',
#  'snoise_sg/s_3251.jpg',
#  'snoise_sg/s_6121.jpg',
#  'snoise_sg/s_4299.jpg',
#  'snoise_sg/s_2577.jpg',
#  'snoise_sg/s_5857.jpg',
#  'snoise_sg/s_3571.jpg',
#  'snoise_sg/s_1038.jpg',
#  'snoise_sg/s_2365.jpg',
#  'snoise_sg/s_5821.jpg',
#  'snoise_sg/s_1316.jpg',
#  'snoise_sg/s_3084.jpg',
#  'snoise_sg/s_6037.jpg',
#  'snoise_sg/s_2027.jpg',
#  'snoise_sg/s_73.jpg',
#  'snoise_sg/s_3536.jpg',
#  'snoise_sg/s_5561.jpg',
#  'snoise_sg/s_953.jpg',
#  'snoise_sg/s_4828.jpg',
#  'snoise_sg/s_4166.jpg',
#  'snoise_sg/s_3643.jpg',
#  'snoise_sg/s_4912.jpg',
#  'snoise_sg/s_990.jpg',
#  'snoise_sg/s_240.jpg',
#  'snoise_sg/s_2850.jpg',
#  'snoise_sg/s_1065.jpg',
#  'snoise_sg/s_19.jpg',
#  'snoise_sg/s_5129.jpg',
#  'snoise_sg/s_2454.jpg',
#  'snoise_sg/s_3221.jpg',
#  'snoise_sg/s_5331.jpg',
#  'snoise_sg/s_4456.jpg',
#  'snoise_sg/s_1064.jpg',
#  'snoise_sg/s_1986.jpg',
#  'snoise_sg/s_4894.jpg',
#  'snoise_sg/s_3151.jpg',
#  'snoise_sg/s_4288.jpg',
#  'snoise_sg/s_4911.jpg',
#  'snoise_sg/s_2253.jpg',
#  'snoise_sg/s_1709.jpg',
#  'snoise_sg/s_4936.jpg',
#  'snoise_sg/s_5823.jpg',
#  'snoise_sg/s_4860.jpg',
#  'snoise_sg/s_5428.jpg',
#  'snoise_sg/s_2558.jpg',
#  'snoise_sg/s_2894.jpg',
#  'snoise_sg/s_1465.jpg',
#  'snoise_sg/s_2372.jpg',
#  'snoise_sg/s_1238.jpg',
#  'snoise_sg/s_5222.jpg',
#  'snoise_sg/s_254.jpg',
#  'snoise_sg/s_3726.jpg',
#  'snoise_sg/s_2557.jpg',
#  'snoise_sg/s_979.jpg',
#  'snoise_sg/s_4213.jpg',
#  'snoise_sg/s_2480.jpg',
#  'snoise_sg/s_4016.jpg',
#  'snoise_sg/s_6402.jpg',
#  'snoise_sg/s_4847.jpg',
#  'snoise_sg/s_1040.jpg',
#  'snoise_sg/s_4566.jpg',
#  'snoise_sg/s_4746.jpg',
#  'snoise_sg/s_3259.jpg',
#  'snoise_sg/s_4402.jpg',
#  'snoise_sg/s_483.jpg',
#  'snoise_sg/s_637.jpg',
#  'snoise_sg/s_6452.jpg',
#  'snoise_sg/s_1539.jpg',
#  'snoise_sg/s_4956.jpg',
#  'snoise_sg/s_3998.jpg',
#  'snoise_sg/s_6180.jpg',
#  'snoise_sg/s_3056.jpg',
#  'snoise_sg/s_1658.jpg',
#  'snoise_sg/s_2845.jpg',
#  'snoise_sg/s_4113.jpg',
#  'snoise_sg/s_3901.jpg',
#  'snoise_sg/s_4279.jpg',
#  'snoise_sg/s_1.jpg',
#  'snoise_sg/s_2256.jpg',
#  'snoise_sg/s_3633.jpg',
#  'snoise_sg/s_5539.jpg',
#  'snoise_sg/s_5048.jpg',
#  'snoise_sg/s_427.jpg',
#  'snoise_sg/s_4492.jpg',
#  'snoise_sg/s_5016.jpg',
#  'snoise_sg/s_1554.jpg',
#  'snoise_sg/s_2953.jpg',
#  'snoise_sg/s_376.jpg',
#  'snoise_sg/s_6230.jpg',
#  'snoise_sg/s_1497.jpg',
#  'snoise_sg/s_3044.jpg',
#  'snoise_sg/s_547.jpg',
#  'snoise_sg/s_2741.jpg',
#  'snoise_sg/s_885.jpg',
#  'snoise_sg/s_1727.jpg',
#  'snoise_sg/s_937.jpg',
#  'snoise_sg/s_3867.jpg',
#  'snoise_sg/s_5471.jpg',
#  'snoise_sg/s_1552.jpg',
#  'snoise_sg/s_2363.jpg',
#  'snoise_sg/s_129.jpg',
#  'snoise_sg/s_1407.jpg',
#  'snoise_sg/s_2117.jpg',
#  'snoise_sg/s_2158.jpg',
#  'snoise_sg/s_1089.jpg',
#  'snoise_sg/s_1012.jpg',
#  'snoise_sg/s_2802.jpg',
#  'snoise_sg/s_330.jpg',
#  'snoise_sg/s_2313.jpg',
#  'snoise_sg/s_4565.jpg',
#  'snoise_sg/s_1916.jpg',
#  'snoise_sg/s_1332.jpg',
#  'snoise_sg/s_1139.jpg',
#  'snoise_sg/s_3134.jpg',
#  'snoise_sg/s_6400.jpg',
#  'snoise_sg/s_3441.jpg',
#  'snoise_sg/s_5410.jpg',
#  'snoise_sg/s_3599.jpg',
#  'snoise_sg/s_430.jpg',
#  'snoise_sg/s_6177.jpg',
#  'snoise_sg/s_1026.jpg',
#  'snoise_sg/s_5999.jpg',
#  'snoise_sg/s_3651.jpg',
#  'snoise_sg/s_3096.jpg',
#  'snoise_sg/s_3285.jpg',
#  'snoise_sg/s_1643.jpg',
#  'snoise_sg/s_2923.jpg',
#  'snoise_sg/s_5383.jpg',
#  'snoise_sg/s_2064.jpg',
#  'snoise_sg/s_3916.jpg',
#  'snoise_sg/s_3050.jpg',
#  'snoise_sg/s_3173.jpg',
#  'snoise_sg/s_5782.jpg',
#  'snoise_sg/s_3184.jpg',
#  'snoise_sg/s_4903.jpg',
#  'snoise_sg/s_2334.jpg',
#  'snoise_sg/s_2800.jpg',
#  'snoise_sg/s_277.jpg',
#  'snoise_sg/s_4663.jpg',
#  'snoise_sg/s_5447.jpg',
#  'snoise_sg/s_4547.jpg',
#  'snoise_sg/s_5585.jpg',
#  'snoise_sg/s_3524.jpg',
#  'snoise_sg/s_918.jpg',
#  'snoise_sg/s_5266.jpg',
#  'snoise_sg/s_6113.jpg',
#  'snoise_sg/s_1377.jpg',
#  'snoise_sg/s_5896.jpg',
#  'snoise_sg/s_1924.jpg',
#  'snoise_sg/s_4333.jpg',
#  'snoise_sg/s_1100.jpg',
#  'snoise_sg/s_6451.jpg',
#  'snoise_sg/s_3423.jpg',
#  'snoise_sg/s_5408.jpg',
#  'snoise_sg/s_2673.jpg',
#  'snoise_sg/s_25.jpg',
#  'snoise_sg/s_1872.jpg',
#  'snoise_sg/s_6466.jpg',
#  'snoise_sg/s_933.jpg',
#  'snoise_sg/s_5736.jpg',
#  'snoise_sg/s_6219.jpg',
#  'snoise_sg/s_3660.jpg',
#  'snoise_sg/s_6459.jpg',
#  'snoise_sg/s_438.jpg',
#  'snoise_sg/s_6320.jpg',
#  'snoise_sg/s_347.jpg',
#  'snoise_sg/s_5800.jpg',
#  'snoise_sg/s_4838.jpg',
#  'snoise_sg/s_6434.jpg',
#  'snoise_sg/s_4295.jpg',
#  'snoise_sg/s_3500.jpg',
#  'snoise_sg/s_315.jpg',
#  'snoise_sg/s_5112.jpg',
#  'snoise_sg/s_1820.jpg',
#  'snoise_sg/s_5118.jpg',
#  'snoise_sg/s_5055.jpg',
#  'snoise_sg/s_4221.jpg',
#  'snoise_sg/s_2909.jpg',
#  'snoise_sg/s_5103.jpg',
#  'snoise_sg/s_1303.jpg',
#  'snoise_sg/s_247.jpg',
#  'snoise_sg/s_2513.jpg',
#  'snoise_sg/s_3260.jpg',
#  'snoise_sg/s_696.jpg',
#  'snoise_sg/s_4578.jpg',
#  'snoise_sg/s_2023.jpg',
#  'snoise_sg/s_377.jpg',
#  'snoise_sg/s_4674.jpg',
#  'snoise_sg/s_1892.jpg',
#  'snoise_sg/s_3569.jpg',
#  'snoise_sg/s_649.jpg',
#  'snoise_sg/s_1045.jpg',
#  'snoise_sg/s_5202.jpg',
#  'snoise_sg/s_2128.jpg',
#  'snoise_sg/s_2772.jpg',
#  'snoise_sg/s_3195.jpg',
#  'snoise_sg/s_1929.jpg',
#  'snoise_sg/s_3305.jpg',
#  'snoise_sg/s_5551.jpg',
#  'snoise_sg/s_1632.jpg',
#  'snoise_sg/s_5011.jpg',
#  'snoise_sg/s_4965.jpg',
#  'snoise_sg/s_353.jpg',
#  'snoise_sg/s_2115.jpg',
#  'snoise_sg/s_195.jpg',
#  'snoise_sg/s_5634.jpg',
#  'snoise_sg/s_3871.jpg',
#  'snoise_sg/s_3205.jpg',
#  'snoise_sg/s_4144.jpg',
#  'snoise_sg/s_820.jpg',
#  'snoise_sg/s_3900.jpg',
#  'snoise_sg/s_6338.jpg',
#  'snoise_sg/s_1197.jpg',
#  'snoise_sg/s_806.jpg',
#  'snoise_sg/s_864.jpg',
#  'snoise_sg/s_1608.jpg',
#  'snoise_sg/s_5326.jpg',
#  'snoise_sg/s_4272.jpg',
#  'snoise_sg/s_256.jpg',
#  'snoise_sg/s_5990.jpg',
#  'snoise_sg/s_1049.jpg',
#  'snoise_sg/s_588.jpg',
#  'snoise_sg/s_1815.jpg',
#  'snoise_sg/s_2550.jpg',
#  'snoise_sg/s_1636.jpg',
#  'snoise_sg/s_5772.jpg',
#  'snoise_sg/s_4241.jpg',
#  'snoise_sg/s_4694.jpg',
#  'snoise_sg/s_1653.jpg',
#  'snoise_sg/s_1690.jpg',
#  'snoise_sg/s_1206.jpg',
#  'snoise_sg/s_301.jpg',
#  'snoise_sg/s_783.jpg',
#  'snoise_sg/s_5520.jpg',
#  'snoise_sg/s_2609.jpg',
#  'snoise_sg/s_468.jpg',
#  'snoise_sg/s_5431.jpg',
#  'snoise_sg/s_3981.jpg',
#  'snoise_sg/s_4597.jpg',
#  'snoise_sg/s_2782.jpg',
#  'snoise_sg/s_5433.jpg',
#  'snoise_sg/s_5994.jpg',
#  'snoise_sg/s_304.jpg',
#  'snoise_sg/s_5193.jpg',
#  'snoise_sg/s_2505.jpg',
#  'snoise_sg/s_1443.jpg',
#  'snoise_sg/s_6067.jpg',
#  'snoise_sg/s_2987.jpg',
#  'snoise_sg/s_3137.jpg',
#  'snoise_sg/s_6172.jpg',
#  'snoise_sg/s_4576.jpg',
#  'snoise_sg/s_4356.jpg',
#  'snoise_sg/s_3976.jpg',
#  'snoise_sg/s_1458.jpg',
#  'snoise_sg/s_4234.jpg',
#  'snoise_sg/s_4001.jpg',
#  'snoise_sg/s_622.jpg',
#  'snoise_sg/s_5917.jpg',
#  'snoise_sg/s_4137.jpg',
#  'snoise_sg/s_3868.jpg',
#  'snoise_sg/s_1294.jpg',
#  'snoise_sg/s_324.jpg',
#  'snoise_sg/s_5784.jpg',
#  'snoise_sg/s_1144.jpg',
#  'snoise_sg/s_4662.jpg',
#  'snoise_sg/s_2928.jpg',
#  'snoise_sg/s_5775.jpg',
#  'snoise_sg/s_5143.jpg',
#  'snoise_sg/s_6069.jpg',
#  'snoise_sg/s_4971.jpg',
#  'snoise_sg/s_6348.jpg',
#  'snoise_sg/s_3030.jpg',
#  'snoise_sg/s_6066.jpg',
#  'snoise_sg/s_5653.jpg',
#  'snoise_sg/s_4433.jpg',
#  'snoise_sg/s_1380.jpg',
#  'snoise_sg/s_3612.jpg',
#  'snoise_sg/s_2793.jpg',
#  'snoise_sg/s_4709.jpg',
#  'snoise_sg/s_5807.jpg',
#  'snoise_sg/s_543.jpg',
#  'snoise_sg/s_432.jpg',
#  'snoise_sg/s_6470.jpg',
#  'snoise_sg/s_3786.jpg',
#  'snoise_sg/s_5334.jpg',
#  'snoise_sg/s_5187.jpg',
#  'snoise_sg/s_705.jpg',
#  'snoise_sg/s_1301.jpg',
#  'snoise_sg/s_5733.jpg',
#  'snoise_sg/s_1388.jpg',
#  'snoise_sg/s_5502.jpg',
#  'snoise_sg/s_4526.jpg',
#  'snoise_sg/s_793.jpg',
#  'snoise_sg/s_3286.jpg',
#  'snoise_sg/s_5933.jpg',
#  'snoise_sg/s_1031.jpg',
#  'snoise_sg/s_6051.jpg',
#  'snoise_sg/s_1023.jpg',
#  'snoise_sg/s_4206.jpg',
#  'snoise_sg/s_1086.jpg',
#  'snoise_sg/s_3336.jpg',
#  'snoise_sg/s_4087.jpg',
#  'snoise_sg/s_495.jpg',
#  'snoise_sg/s_6093.jpg',
#  'snoise_sg/s_3115.jpg',
#  'snoise_sg/s_2745.jpg',
#  'snoise_sg/s_4149.jpg',
#  'snoise_sg/s_1427.jpg',
#  'snoise_sg/s_3773.jpg',
#  'snoise_sg/s_4197.jpg',
#  'snoise_sg/s_1496.jpg',
#  'snoise_sg/s_2635.jpg',
#  'snoise_sg/s_1702.jpg',
#  'snoise_sg/s_2335.jpg',
#  'snoise_sg/s_4369.jpg',
#  'snoise_sg/s_2249.jpg',
#  'snoise_sg/s_2785.jpg',
#  'snoise_sg/s_1895.jpg',
#  'snoise_sg/s_758.jpg',
#  'snoise_sg/s_3898.jpg',
#  'snoise_sg/s_1673.jpg',
#  'snoise_sg/s_4043.jpg',
#  'snoise_sg/s_6363.jpg',
#  'snoise_sg/s_454.jpg',
#  'snoise_sg/s_1408.jpg',
#  'snoise_sg/s_5123.jpg',
#  'snoise_sg/s_1270.jpg',
#  'snoise_sg/s_812.jpg',
#  'snoise_sg/s_6260.jpg',
#  'snoise_sg/s_2807.jpg',
#  'snoise_sg/s_4030.jpg',
#  'snoise_sg/s_367.jpg',
#  'snoise_sg/s_4318.jpg',
#  'snoise_sg/s_6283.jpg',
#  'snoise_sg/s_3178.jpg',
#  'snoise_sg/s_2341.jpg',
#  'snoise_sg/s_2935.jpg',
#  'snoise_sg/s_6165.jpg',
#  'snoise_sg/s_2582.jpg',
#  'snoise_sg/s_1171.jpg',
#  'snoise_sg/s_3275.jpg',
#  'snoise_sg/s_1090.jpg',
#  'snoise_sg/s_917.jpg',
#  'snoise_sg/s_5295.jpg',
#  'snoise_sg/s_5804.jpg',
#  'snoise_sg/s_6002.jpg',
#  'snoise_sg/s_1570.jpg',
#  'snoise_sg/s_109.jpg',
#  'snoise_sg/s_5031.jpg',
#  'snoise_sg/s_1007.jpg',
#  'snoise_sg/s_6143.jpg',
#  'snoise_sg/s_6211.jpg',
#  'snoise_sg/s_824.jpg',
#  'snoise_sg/s_747.jpg',
#  'snoise_sg/s_309.jpg',
#  'snoise_sg/s_3098.jpg',
#  'snoise_sg/s_2677.jpg',
#  'snoise_sg/s_1406.jpg',
#  'snoise_sg/s_3591.jpg',
#  'snoise_sg/s_5944.jpg',
#  'snoise_sg/s_4463.jpg',
#  'snoise_sg/s_534.jpg',
#  'snoise_sg/s_3376.jpg',
#  'snoise_sg/s_1861.jpg',
#  'snoise_sg/s_895.jpg',
#  'snoise_sg/s_3075.jpg',
#  'snoise_sg/s_905.jpg',
#  'snoise_sg/s_4294.jpg',
#  'snoise_sg/s_202.jpg',
#  'snoise_sg/s_927.jpg',
#  'snoise_sg/s_5701.jpg',
#  'snoise_sg/s_3330.jpg',
#  'snoise_sg/s_6071.jpg',
#  'snoise_sg/s_1634.jpg',
#  'snoise_sg/s_5168.jpg',
#  'snoise_sg/s_4227.jpg',
#  'snoise_sg/s_428.jpg',
#  'snoise_sg/s_5480.jpg',
#  'snoise_sg/s_4196.jpg',
#  'snoise_sg/s_2086.jpg',
#  'snoise_sg/s_3582.jpg',
#  'snoise_sg/s_2241.jpg',
#  'snoise_sg/s_3631.jpg',
#  'snoise_sg/s_5307.jpg',
#  'snoise_sg/s_1899.jpg',
#  'snoise_sg/s_4845.jpg',
#  'snoise_sg/s_5954.jpg',
#  'snoise_sg/s_6334.jpg',
#  'snoise_sg/s_6226.jpg',
#  'snoise_sg/s_3101.jpg',
#  'snoise_sg/s_2054.jpg',
#  'snoise_sg/s_5741.jpg',
#  'snoise_sg/s_5877.jpg',
#  'snoise_sg/s_6212.jpg',
#  'snoise_sg/s_3045.jpg',
#  'snoise_sg/s_2754.jpg',
#  'snoise_sg/s_5492.jpg',
#  'snoise_sg/s_5244.jpg',
#  'snoise_sg/s_6114.jpg',
#  'snoise_sg/s_1193.jpg',
#  'snoise_sg/s_3634.jpg',
#  'snoise_sg/s_5192.jpg',
#  'snoise_sg/s_1082.jpg',
#  'snoise_sg/s_6236.jpg',
#  'snoise_sg/s_4102.jpg',
#  'snoise_sg/s_1477.jpg',
#  'snoise_sg/s_1884.jpg',
#  'snoise_sg/s_2013.jpg',
#  'snoise_sg/s_3265.jpg',
#  'snoise_sg/s_1808.jpg',
#  'snoise_sg/s_1587.jpg',
#  'snoise_sg/s_941.jpg',
#  'snoise_sg/s_5166.jpg',
#  'snoise_sg/s_1721.jpg',
#  'snoise_sg/s_4335.jpg',
#  'snoise_sg/s_4263.jpg',
#  'snoise_sg/s_2837.jpg',
#  'snoise_sg/s_772.jpg',
#  'snoise_sg/s_2477.jpg',
#  'snoise_sg/s_5783.jpg',
#  'snoise_sg/s_117.jpg',
#  'snoise_sg/s_2319.jpg',
#  'snoise_sg/s_3395.jpg',
#  'snoise_sg/s_6235.jpg',
#  'snoise_sg/s_2122.jpg',
#  'snoise_sg/s_2168.jpg',
#  'snoise_sg/s_4538.jpg',
#  'snoise_sg/s_1598.jpg',
#  'snoise_sg/s_2459.jpg',
#  'snoise_sg/s_5534.jpg',
#  'snoise_sg/s_2824.jpg',
#  'snoise_sg/s_3025.jpg',
#  'snoise_sg/s_6101.jpg',
#  'snoise_sg/s_4579.jpg',
#  'snoise_sg/s_3671.jpg',
#  'snoise_sg/s_2573.jpg',
#  'snoise_sg/s_788.jpg',
#  'snoise_sg/s_5146.jpg',
#  'snoise_sg/s_5267.jpg',
#  'snoise_sg/s_4437.jpg',
#  'snoise_sg/s_54.jpg',
#  'snoise_sg/s_2129.jpg',
#  'snoise_sg/s_1228.jpg',
#  'snoise_sg/s_6256.jpg',
#  'snoise_sg/s_3943.jpg',
#  'snoise_sg/s_4051.jpg',
#  'snoise_sg/s_2799.jpg',
#  'snoise_sg/s_2962.jpg',
#  'snoise_sg/s_6119.jpg',
#  'snoise_sg/s_29.jpg',
#  'snoise_sg/s_3861.jpg',
#  'snoise_sg/s_5156.jpg',
#  'snoise_sg/s_113.jpg',
#  'snoise_sg/s_3079.jpg',
#  'snoise_sg/s_5150.jpg',
#  'snoise_sg/s_343.jpg',
#  'snoise_sg/s_3613.jpg',
#  'snoise_sg/s_322.jpg',
#  'snoise_sg/s_580.jpg',
#  'snoise_sg/s_3676.jpg',
#  'snoise_sg/s_2066.jpg',
#  'snoise_sg/s_2071.jpg',
#  'snoise_sg/s_6259.jpg',
#  'snoise_sg/s_2954.jpg',
#  'snoise_sg/s_4714.jpg',
#  'snoise_sg/s_4832.jpg',
#  'snoise_sg/s_830.jpg',
#  'snoise_sg/s_569.jpg',
#  'snoise_sg/s_3974.jpg',
#  'snoise_sg/s_884.jpg',
#  'snoise_sg/s_921.jpg',
#  'snoise_sg/s_3595.jpg',
#  'snoise_sg/s_4003.jpg',
#  'snoise_sg/s_1610.jpg',
#  'snoise_sg/s_4943.jpg',
#  'snoise_sg/s_1811.jpg',
#  'snoise_sg/s_2343.jpg',
#  'snoise_sg/s_1036.jpg',
#  'snoise_sg/s_3156.jpg',
#  'snoise_sg/s_2566.jpg',
#  'snoise_sg/s_3875.jpg',
#  'snoise_sg/s_700.jpg',
#  'snoise_sg/s_2448.jpg',
#  'snoise_sg/s_191.jpg',
#  'snoise_sg/s_3533.jpg',
#  'snoise_sg/s_2985.jpg',
#  'snoise_sg/s_1630.jpg',
#  'snoise_sg/s_4708.jpg',
#  'snoise_sg/s_6062.jpg',
#  'snoise_sg/s_5231.jpg',
#  'snoise_sg/s_5214.jpg',
#  'snoise_sg/s_3262.jpg',
#  'snoise_sg/s_1760.jpg',
#  'snoise_sg/s_836.jpg',
#  'snoise_sg/s_1841.jpg',
#  'snoise_sg/s_5699.jpg',
#  'snoise_sg/s_5458.jpg',
#  'snoise_sg/s_2572.jpg',
#  'snoise_sg/s_1025.jpg',
#  'snoise_sg/s_6255.jpg',
#  'snoise_sg/s_4004.jpg',
#  'snoise_sg/s_141.jpg',
#  'snoise_sg/s_3598.jpg',
#  'snoise_sg/s_2231.jpg',
#  'snoise_sg/s_3471.jpg',
#  'snoise_sg/s_5067.jpg',
#  'snoise_sg/s_5065.jpg',
#  'snoise_sg/s_1244.jpg',
#  'snoise_sg/s_1125.jpg',
#  'snoise_sg/s_4417.jpg',
#  'snoise_sg/s_3456.jpg',
#  'snoise_sg/s_857.jpg',
#  'snoise_sg/s_3348.jpg',
#  'snoise_sg/s_1782.jpg',
#  'snoise_sg/s_1200.jpg',
#  'snoise_sg/s_2560.jpg',
#  'snoise_sg/s_4629.jpg',
#  'snoise_sg/s_394.jpg',
#  'snoise_sg/s_334.jpg',
#  'snoise_sg/s_4245.jpg',
#  'snoise_sg/s_1524.jpg',
#  'snoise_sg/s_3615.jpg',
#  'snoise_sg/s_2465.jpg',
#  'snoise_sg/s_4739.jpg',
#  'snoise_sg/s_2426.jpg',
#  'snoise_sg/s_3811.jpg',
#  'snoise_sg/s_2308.jpg',
#  'snoise_sg/s_5015.jpg',
#  'snoise_sg/s_2076.jpg',
#  'snoise_sg/s_3360.jpg',
#  'snoise_sg/s_1676.jpg',
#  'snoise_sg/s_3085.jpg',
#  'snoise_sg/s_1859.jpg',
#  'snoise_sg/s_441.jpg',
#  'snoise_sg/s_4029.jpg',
#  'snoise_sg/s_1611.jpg',
#  'snoise_sg/s_5145.jpg',
#  'snoise_sg/s_5238.jpg',
#  'snoise_sg/s_5583.jpg',
#  'snoise_sg/s_6364.jpg',
#  'snoise_sg/s_6122.jpg',
#  'snoise_sg/s_6275.jpg',
#  'snoise_sg/s_2070.jpg',
#  'snoise_sg/s_1593.jpg',
#  'snoise_sg/s_4889.jpg',
#  'snoise_sg/s_445.jpg',
#  'snoise_sg/s_5132.jpg',
#  'snoise_sg/s_399.jpg',
#  'snoise_sg/s_4475.jpg',
#  'snoise_sg/s_1704.jpg',
#  'snoise_sg/s_6355.jpg',
#  'snoise_sg/s_2171.jpg',
#  'snoise_sg/s_3309.jpg',
#  'snoise_sg/s_3100.jpg',
#  'snoise_sg/s_878.jpg',
#  'snoise_sg/s_697.jpg',
#  'snoise_sg/s_4054.jpg',
#  'snoise_sg/s_258.jpg',
#  'snoise_sg/s_5754.jpg',
#  'snoise_sg/s_4557.jpg',
#  'snoise_sg/s_1842.jpg',
#  'snoise_sg/s_2225.jpg',
#  'snoise_sg/s_3158.jpg',
#  'snoise_sg/s_5495.jpg',
#  'snoise_sg/s_2591.jpg',
#  'snoise_sg/s_3609.jpg',
#  'snoise_sg/s_794.jpg',
#  'snoise_sg/s_599.jpg',
#  'snoise_sg/s_4985.jpg',
#  'snoise_sg/s_5241.jpg',
#  'snoise_sg/s_76.jpg',
#  'snoise_sg/s_1877.jpg',
#  'snoise_sg/s_4326.jpg',
#  'snoise_sg/s_477.jpg',
#  'snoise_sg/s_5524.jpg',
#  'snoise_sg/s_2633.jpg',
#  'snoise_sg/s_5366.jpg',
#  'snoise_sg/s_4081.jpg',
#  'snoise_sg/s_4979.jpg',
#  'snoise_sg/s_4810.jpg',
#  'snoise_sg/s_5696.jpg',
#  'snoise_sg/s_6436.jpg',
#  'snoise_sg/s_3236.jpg',
#  'snoise_sg/s_5315.jpg',
#  'snoise_sg/s_1666.jpg',
#  'snoise_sg/s_1155.jpg',
#  'snoise_sg/s_5135.jpg',
#  'snoise_sg/s_4808.jpg',
#  'snoise_sg/s_1551.jpg',
#  'snoise_sg/s_4203.jpg',
#  'snoise_sg/s_694.jpg',
#  'snoise_sg/s_4555.jpg',
#  'snoise_sg/s_1390.jpg',
#  'snoise_sg/s_4546.jpg',
#  'snoise_sg/s_3506.jpg',
#  'snoise_sg/s_6181.jpg',
#  'snoise_sg/s_1787.jpg',
#  'snoise_sg/s_3018.jpg',
#  'snoise_sg/s_5867.jpg',
#  'snoise_sg/s_290.jpg']

# %%
image_count = len(anchor_images)

anchor_dataset = tf.data.Dataset.from_tensor_slices(anchor_images)
positive_dataset = tf.data.Dataset.from_tensor_slices(positive_images)

# To generate the list of negative images, let's randomize the list of
# available images and concatenate them together.
rng = np.random.RandomState(seed=42)
rng.shuffle(anchor_images)
rng.shuffle(positive_images)

negative_images = anchor_images + positive_images
np.random.RandomState(seed=32).shuffle(negative_images)

negative_dataset = tf.data.Dataset.from_tensor_slices(negative_images)
negative_dataset = negative_dataset.shuffle(buffer_size=4096)

dataset = tf.data.Dataset.zip((anchor_dataset, positive_dataset, negative_dataset))
dataset = dataset.shuffle(buffer_size=1024)
dataset = dataset.map(preprocess_triplets)

# Let's now split our dataset in train and validation.
train_dataset = dataset.take(round(image_count * 0.8))
val_dataset = dataset.skip(round(image_count * 0.8))

train_dataset = train_dataset.batch(32, drop_remainder=False)
train_dataset = train_dataset.prefetch(8)

val_dataset = val_dataset.batch(32, drop_remainder=False)
val_dataset = val_dataset.prefetch(8)

# %%
def visualize(anchor, positive, negative):
    """Visualize a few triplets from the supplied batches."""

    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(9, 9))

    axs = fig.subplots(3, 3)
    for i in range(3):
        show(axs[i, 0], anchor[i])
        show(axs[i, 1], positive[i])
        show(axs[i, 2], negative[i])


visualize(*list(train_dataset.take(1).as_numpy_iterator())[0])

# %%
base_cnn = resnet.ResNet50(
    weights="imagenet", input_shape=target_shape + (3,), include_top=False
)

flatten = layers.Flatten()(base_cnn.output)
dense1 = layers.Dense(512, activation="relu")(flatten)
dense1 = layers.BatchNormalization()(dense1)
dense2 = layers.Dense(256, activation="relu")(dense1)
dense2 = layers.BatchNormalization()(dense2)
output = layers.Dense(256)(dense2)

embedding = Model(base_cnn.input, output, name="Embedding")

trainable = False
for layer in base_cnn.layers:
    if layer.name == "conv5_block1_out":
        trainable = True
    layer.trainable = trainable

# %%
class DistanceLayer(layers.Layer):
    """
    This layer is responsible for computing the distance between the anchor
    embedding and the positive embedding, and the anchor embedding and the
    negative embedding.
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, positive, negative):
        ap_distance = tf.reduce_sum(tf.square(anchor - positive), -1)
        an_distance = tf.reduce_sum(tf.square(anchor - negative), -1)
        return (ap_distance, an_distance)


anchor_input = layers.Input(name="anchor", shape=target_shape + (3,))
positive_input = layers.Input(name="positive", shape=target_shape + (3,))
negative_input = layers.Input(name="negative", shape=target_shape + (3,))

distances = DistanceLayer()(
    embedding(resnet.preprocess_input(anchor_input)),
    embedding(resnet.preprocess_input(positive_input)),
    embedding(resnet.preprocess_input(negative_input)),
)

siamese_network = Model(
    inputs=[anchor_input, positive_input, negative_input], outputs=distances
)

# %%
class SiameseModel(Model):
    """The Siamese Network model with a custom training and testing loops.

    Computes the triplet loss using the three embeddings produced by the
    Siamese Network.

    The triplet loss is defined as:
       L(A, P, N) = max(‖f(A) - f(P)‖² - ‖f(A) - f(N)‖² + margin, 0)
    """

    def __init__(self, siamese_network, margin=0.5):
        super(SiameseModel, self).__init__()
        self.siamese_network = siamese_network
        self.margin = margin
        self.loss_tracker = metrics.Mean(name="loss")

    def call(self, inputs):
        return self.siamese_network(inputs)

    def train_step(self, data):
        # GradientTape is a context manager that records every operation that
        # you do inside. We are using it here to compute the loss so we can get
        # the gradients and apply them using the optimizer specified in
        # `compile()`.
        with tf.GradientTape() as tape:
            loss = self._compute_loss(data)

        # Storing the gradients of the loss function with respect to the
        # weights/parameters.
        gradients = tape.gradient(loss, self.siamese_network.trainable_weights)

        # Applying the gradients on the model using the specified optimizer
        self.optimizer.apply_gradients(
            zip(gradients, self.siamese_network.trainable_weights)
        )

        # Let's update and return the training loss metric.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        loss = self._compute_loss(data)

        # Let's update and return the loss metric.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def _compute_loss(self, data):
        # The output of the network is a tuple containing the distances
        # between the anchor and the positive example, and the anchor and
        # the negative example.
        ap_distance, an_distance = self.siamese_network(data)

        # Computing the Triplet Loss by subtracting both distances and
        # making sure we don't get a negative value.
        loss = ap_distance - an_distance
        loss = tf.maximum(loss + self.margin, 0.0)
        return loss

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker]

# %%
siamese_model = SiameseModel(siamese_network)
siamese_model.compile(optimizer=optimizers.Adam(0.0001))
siamese_model.fit(train_dataset,batch_size=256, epochs=10, validation_data=val_dataset)
